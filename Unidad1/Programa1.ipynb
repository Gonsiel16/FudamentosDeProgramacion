# %% [markdown]
# <a href="https://colab.research.google.com/github/Gonsiel16/FudamentosDeProgramacion/blob/main/Unidad1/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
X = "Carlos"
variableBooleana= True
print ("Hola", x, X, "X", variableBooleana)
# Out:
# Hola 5 Carlos X True

# %%
base = input("Dame la base del triangulo: ")
altura = input("Dame la altura del triangulo: ")
area = (int(base)) * (int(altura))/2
print("El area del triangulo es", area)
# Out:
# Dame la base del triangulo: 45
# Dame la altura del triangulo: 643
# El area del triangulo es 14467.5

# %%
z = 10
a = "hola"
print(z * a)
# Out:
# holaholaholaholaholaholaholaholaholahola

# %%
numero1 = 20
numero2 = 20
if numero1 > numero2:
    print("El numero", numero1, "es mayor que", numero2)
elif numero1 == numero2:
    print(numero1, "y", numero2, "son iguales")
else:
    print("El numero", numero2, "es mayor que", numero1)
# Out:
# 20 y 20 son iguales

# %%
edad = int(input("Dame tu edad: "))
if (int(edad) >= 0 and edad <=6):
    print("bebe")
elif(int(edad) >= 7 and edad <=12):
    print("niño")
elif(int(edad) >=13 and edad <=17):
    print("adolescente")
elif(int(edad) >=18 and edad <=25):
    print("adulto joven")
elif(int(edad) >=26 and edad <=50):
    print("adulto mayor")
# Out:
# Dame tu edad: 6
# bebe
